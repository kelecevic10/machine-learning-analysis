# %% [markdown]
# ## Ucitavanje podataka

# %%
import os
import glob 
import numpy as np 
import pandas as pd

from sklearn.model_selection import train_test_split

# %%
RAW_DATA_PATH = "../data/raw"
PROCESSED_DATA_PATH = "../data/processed"

# %%
csv_files = glob.glob(os.path.join(RAW_DATA_PATH, "*.csv"))
print(f"Total files found: {len(csv_files)}")
# Out:
# Total files found: 153

# %%
X_list = []
y_list = []

font_list = []
strength_list = []
italic_list = []

total_rows = 0

for i, file in enumerate(csv_files):
    print(f"Loading file {i+1}/{len(csv_files)}: {file}")

    df = pd.read_csv(file)
    pixel_columns = [col for col in df.columns if col.startswith("r")]

    X_batch = df[pixel_columns].values.astype(np.uint8)
    y_batch = df["m_label"].values.astype(np.uint8)

    font_batch = df["font"].values
    strength_batch = df["strength"].values.astype(np.float32)
    italic_batch = df["italic"].values.astype(np.uint8)

    X_list.append(X_batch)
    y_list.append(y_batch)

    font_list.append(font_batch)
    strength_list.append(strength_batch)
    italic_list.append(italic_batch)

    total_rows += X_batch.shape[0]

    del df
total_rows
# Out:
# Loading file 1/153: ../data/raw/BODONI.csv
# Loading file 2/153: ../data/raw/PHAGSPA.csv
# Loading file 3/153: ../data/raw/GARAMOND.csv
# Loading file 4/153: ../data/raw/SANSSERIF.csv
# Loading file 5/153: ../data/raw/LEELAWADEE.csv
# Loading file 6/153: ../data/raw/FORTE.csv
# Loading file 7/153: ../data/raw/PALACE.csv
# Loading file 8/153: ../data/raw/MODERN.csv
# Loading file 9/153: ../data/raw/IMPACT.csv
# Loading file 10/153: ../data/raw/COURIER.csv
# Loading file 11/153: ../data/raw/CAARD.csv
# Loading file 12/153: ../data/raw/MONOTYPE.csv
# Loading file 13/153: ../data/raw/NINA.csv
# Loading file 14/153: ../data/raw/CASTELLAR.csv
# Loading file 15/153: ../data/raw/CALIBRI.csv
# Loading file 16/153: ../data/raw/CALISTO.csv
# Loading file 17/153: ../data/raw/ISOC.csv
# Loading file 18/153: ../data/raw/ITALIC.csv
# Loading file 19/153: ../data/raw/BLACKADDER.csv
# Loading file 20/153: ../data/raw/JUICE.csv
# Loading file 21/153: ../data/raw/VLADIMIR.csv
# Loading file 22/153: ../data/raw/KUNSTLER.csv
# Loading file 23/153: ../data/raw/COUNTRYBLUEPRINT.csv
# Loading file 24/153: ../data/raw/INFORMAL.csv
# Loading file 25/153: ../data/raw/EDWARDIAN.csv
# Loading file 26/153: ../data/raw/CORBEL.csv
# Loading file 27/153: ../data/raw/FELIX TITLING.csv
# Loading file 28/153: ../data/raw/CALIFORNIAN.csv
# Loading file 29/153: ../data/raw/TAI.csv
# Loading file 30/153: ../data/raw/OCRB.csv
# Loading file 31/153: ../data/raw/CITYBLUEPRINT.csv
# Loading file 32/153: ../data/raw/COMPLEX.csv
# Loading file 33/153: ../data/raw/PAPYRUS.csv
# Loading file 34/153: ../data/raw/BELL.csv
# Loading file 35/153: ../data/raw/TXT.csv
# Loading file 36/153: ../data/raw/CONSTANTIA.csv
# Loading file 37/153: ../data/raw/QUICKTYPE.csv
# Loading file 38/153: ../data/raw/CENTURY.csv
# Loading file 39/153: ../data/raw/VINETA.csv
# Loading file 40/153: ../data/raw/ELEPHANT.csv
# Loading file 41/153: ../data/raw/ENGRAVERS.csv
# Loading file 103/153: ../data/raw/FOOTLIGHT.csv
# Loading file 104/153: ../data/raw/MAGNETO.csv
# Loading file 105/153: ../data/raw/YI BAITI.csv
# Loading file 106/153: ../data/raw/PROXY.csv
# Loading file 107/153: ../data/raw/IMPRINT.csv
# Loading file 108/153: ../data/raw/PMINGLIU-EXTB.csv
# Loading file 109/153: ../data/raw/COMMERCIALSCRIPT.csv
# Loading file 110/153: ../data/raw/CHILLER.csv
# Loading file 111/153: ../data/raw/GIGI.csv
# Loading file 112/153: ../data/raw/ROCKWELL.csv
# Loading file 113/153: ../data/raw/EBRIMA.csv
# Loading file 114/153: ../data/raw/ARIAL.csv
# Loading file 115/153: ../data/raw/PALATINO.csv
# Loading file 116/153: ../data/raw/STYLUS.csv
# Loading file 117/153: ../data/raw/E13B.csv
# Loading file 118/153: ../data/raw/PRISTINA.csv
# Loading file 119/153: ../data/raw/CENTAUR.csv
# Loading file 120/153: ../data/raw/SYLFAEN.csv
# Loading file 121/153: ../data/raw/SCRIPT.csv
# Loading file 122/153: ../data/raw/SERIF.csv
# Loading file 123/153: ../data/raw/MONOSPAC821.csv
# Loading file 124/153: ../data/raw/BUXTON.csv
# Loading file 125/153: ../data/raw/GUNPLAY.csv
# Loading file 126/153: ../data/raw/MONEY.csv
# Loading file 127/153: ../data/raw/CANDARA.csv
# Loading file 128/153: ../data/raw/COOPER.csv
# Loading file 129/153: ../data/raw/MAIANDRA.csv
# Loading file 130/153: ../data/raw/HIGH TOWER.csv
# Loading file 131/153: ../data/raw/HAETTENSCHWEILER.csv
# Loading file 132/153: ../data/raw/MINGLIU.csv
# Loading file 133/153: ../data/raw/STENCIL.csv
# Loading file 134/153: ../data/raw/OCRA.csv
# Loading file 135/153: ../data/raw/SEGOE.csv
# Loading file 136/153: ../data/raw/MYANMAR.csv
# Loading file 137/153: ../data/raw/BAUHAUS.csv
# Loading file 138/153: ../data/raw/HARLOW.csv
# Loading file 139/153: ../data/raw/SKETCHFLOW.csv
# Loading file 140/153: ../data/raw/VIVALDI.csv
# Loading file 141/153: ../data/raw/JOKERMAN.csv
# Loading file 142/153: ../data/raw/JAVANESE.csv
# Loading file 143/153: ../data/raw/FRENCH.csv
# Loading file 144/153: ../data/raw/BANKGOTHIC.csv
# Loading file 145/153: ../data/raw/EUROROMAN.csv
# Loading file 146/153: ../data/raw/VINER.csv
# Loading file 147/153: ../data/raw/KRISTEN.csv
# Loading file 148/153: ../data/raw/ENGLISH.csv
# Loading file 149/153: ../data/raw/DUTCH801.csv
# Loading file 150/153: ../data/raw/BRUSH.csv
# Loading file 151/153: ../data/raw/REFERENCE.csv
# Loading file 152/153: ../data/raw/ERAS.csv
# Loading file 153/153: ../data/raw/COPPERPLATE.csv
# 832670

# %%
X = np.vstack(X_list)
y = np.concatenate(y_list)

font = np.concatenate(font_list)
strength = np.concatenate(strength_list)
italic = np.concatenate(italic_list)

print("Final X shape: ", X.shape)
print("Final y shape: ", y.shape)
print("Final font shape: ", font.shape)
print("Final strength shape: ", strength.shape)
print("Final italic shape: ", italic.shape)

print("\ncheck the same number of samples:")
print("X vs y: ", X.shape[0] == y.shape[0])
print("X vs font: ", X.shape[0] == font.shape[0])
print("X vs strength: ", X.shape[0] == strength.shape[0])
print("X vs italic: ", X.shape[0] == italic.shape[0])

del X_list
del y_list
del font_list
del strength_list
del italic_list
# Out:
# Final X shape:  (832670, 400)
# Final y shape:  (832670,)
# Final font shape:  (832670,)
# Final strength shape:  (832670,)
# Final italic shape:  (832670,)
#
# check the same number of samples:
# X vs y:  True
# X vs font:  True
# X vs strength:  True
# X vs italic:  True

# %% [markdown]
# ## Validacija podataka

# %%
print("Minimal pixel value: ", X.min())
print("Maximal pixel value: ", X.max())

print("Does X contain any NaN: ", np.isnan(X).any())
print("Does y contain any NaN: ", np.isnan(y).any())
print("Does strength contain any NaN: ", np.isnan(strength).any())

print("\nUnique y classes: ", len(np.unique(y)))
print("Unique fonts: ", len(np.unique(font)))
print("Italic values: ", np.unique(italic))
# Out:
# Minimal pixel value:  0
# Maximal pixel value:  255
# Does X contain any NaN:  False
# Does y contain any NaN:  False
# Does strength contain any NaN:  False
#
# Unique y classes:  256
# Unique fonts:  153
# Italic values:  [0 1]

# %% [markdown]
# ### Balansiranost klasa

# %%
unique, counts = np.unique(y, return_counts = True)
for class_name, count in zip(unique, counts):
    class_name = str(class_name)
    print(f"Class {class_name}: {count} samples")
# Out:
# Class 0: 1467 samples
# Class 1: 2216 samples
# Class 2: 3193 samples
# Class 3: 1606 samples
# Class 4: 1560 samples
# Class 5: 1693 samples
# Class 6: 2214 samples
# Class 7: 1423 samples
# Class 8: 1325 samples
# Class 9: 1238 samples
# Class 10: 1242 samples
# Class 11: 1251 samples
# Class 12: 1598 samples
# Class 13: 1180 samples
# Class 14: 1339 samples
# Class 15: 2068 samples
# Class 16: 1979 samples
# Class 17: 2090 samples
# Class 18: 1952 samples
# Class 19: 2384 samples
# Class 20: 2311 samples
# Class 21: 2313 samples
# Class 22: 1656 samples
# Class 23: 1733 samples
# Class 24: 2530 samples
# Class 25: 3063 samples
# Class 26: 3055 samples
# Class 27: 1871 samples
# Class 28: 2243 samples
# Class 29: 2125 samples
# Class 30: 2901 samples
# Class 31: 1572 samples
# Class 32: 2275 samples
# Class 33: 5191 samples
# Class 34: 4990 samples
# Class 35: 4420 samples
# Class 36: 5308 samples
# Class 37: 3418 samples
# Class 38: 4482 samples
# Class 39: 2385 samples
# Class 40: 4359 samples
# Class 41: 4389 samples
# Class 42: 4281 samples
# Class 43: 5957 samples
# Class 44: 4238 samples
# Class 45: 4286 samples
# Class 46: 4526 samples
# Class 47: 5107 samples
# Class 48: 30142 samples
# Class 49: 30665 samples
# Class 50: 23590 samples
# Class 51: 21859 samples
# Class 52: 22616 samples
# Class 53: 19680 samples
# Class 54: 23632 samples
# Class 55: 19323 samples
# Class 56: 21905 samples
# Class 57: 19509 samples
# Class 58: 3346 samples
# Class 59: 2294 samples
# Class 60: 10245 samples
# Class 61: 2398 samples
# Class 62: 6208 samples
# Class 63: 2342 samples
# Class 64: 2518 samples
# Class 65: 5728 samples
# Class 66: 5496 samples
# Class 67: 4810 samples
# Class 68: 5427 samples
# Class 69: 4767 samples
# Class 70: 4137 samples
# Class 71: 4759 samples
# Class 72: 5328 samples
# Class 73: 4556 samples
# Class 74: 4574 samples
# Class 75: 4465 samples
# Class 76: 4503 samples
# Class 77: 4909 samples
# Class 78: 4977 samples
# Class 79: 3946 samples
# Class 80: 4584 samples
# Class 208: 1691 samples
# Class 209: 2589 samples
# Class 210: 1695 samples
# Class 211: 1713 samples
# Class 212: 1657 samples
# Class 213: 1665 samples
# Class 214: 1741 samples
# Class 215: 1695 samples
# Class 216: 2557 samples
# Class 217: 2507 samples
# Class 218: 2449 samples
# Class 219: 2349 samples
# Class 220: 2453 samples
# Class 221: 2361 samples
# Class 222: 1691 samples
# Class 223: 1699 samples
# Class 224: 1715 samples
# Class 225: 1707 samples
# Class 226: 1707 samples
# Class 227: 1736 samples
# Class 228: 1713 samples
# Class 229: 1709 samples
# Class 230: 1944 samples
# Class 231: 1776 samples
# Class 232: 1768 samples
# Class 233: 1768 samples
# Class 234: 1808 samples
# Class 235: 1756 samples
# Class 236: 1764 samples
# Class 237: 1764 samples
# Class 238: 1772 samples
# Class 239: 1768 samples
# Class 240: 1713 samples
# Class 241: 1709 samples
# Class 242: 2005 samples
# Class 243: 1917 samples
# Class 244: 1793 samples
# Class 245: 1597 samples
# Class 246: 1653 samples
# Class 247: 1681 samples
# Class 248: 1677 samples
# Class 249: 1683 samples
# Class 250: 1803 samples
# Class 251: 1815 samples
# Class 252: 1836 samples
# Class 253: 1814 samples
# Class 254: 1791 samples
# Class 255: 843 samples

# %% [markdown]
# Provera m_label kolone u originalnim podacima

# %%
print("===== Character label info =====")
print("Broj klasa:", len(np.unique(y)))
print("Min label:", y.min())
print("Max label:", y.max())

print("\n===== Font info =====")
print("Broj fontova:", len(np.unique(font)))

print("\n===== Italic info =====")
print("Unique italic values:", np.unique(italic))

print("\n===== Strength info =====")
print("Min strength:", strength.min())
print("Max strength:", strength.max())
# Out:
# ===== Character label info =====
# Broj klasa: 256
# Min label: 0
# Max label: 255
#
# ===== Font info =====
# Broj fontova: 153
#
# ===== Italic info =====
# Unique italic values: [0 1]
#
# ===== Strength info =====
# Min strength: 0.4
# Max strength: 0.7

# %% [markdown]
# ### Konverzija podataka uint8 -> float32 za rad sa modelima

# %%
X = X.astype(np.float32)
print(X.dtype)
# Out:
# float32

# %% [markdown]
# ### Stratified train-test split

# %%
X_train, X_test, \
y_train, y_test, \
font_train, font_test, \
strength_train, strength_test, \
italic_train, italic_test = train_test_split(
    X,
    y,
    font,
    strength,
    italic,
    test_size = 0.2,
    random_state = 42,
    stratify = y
)

print("X Train shape: ", X_train.shape)
print("X Test shape: ", X_test.shape)

print("y Train shape: ", y_train.shape)
print("y Test shape: ", y_test.shape)

print("Font Train shape: ", font_train.shape)
print("Strength Train shape: ", strength_train.shape)
print("Italic Train shape: ", italic_train.shape)
# Out:
# X Train shape:  (666136, 400)
# X Test shape:  (166534, 400)
# y Train shape:  (666136,)
# y Test shape:  (166534,)
# Font Train shape:  (666136,)
# Strength Train shape:  (666136,)
# Italic Train shape:  (666136,)

# %% [markdown]
# ### Cuvanje preprocessed dataset-a

# %%
output_path = os.path.join(PROCESSED_DATA_PATH, "preprocessed.npz")

np.savez_compressed(
    output_path,
    X_train = X_train,
    X_test = X_test,
    y_train = y_train,
    y_test = y_test,
    font_train = font_train,
    strength_train = strength_train,
    strength_test = strength_test,
    italic_train = italic_train,
    italic_test = italic_test
)

print(f"Dataset successfully saved in: {output_path}")
# Out:
# Dataset successfully saved in: ../data/processed/preprocessed.npz
